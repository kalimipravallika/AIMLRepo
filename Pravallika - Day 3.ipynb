# %% [markdown]
# # 1. write a python function that copies a file reading and writing up to 50 characters at a time

# %%
def solve(input_file, output_file):
    
    with open(input_file, 'r') as inp, open(output_file, 'w') as out:
        while True:
            data = inp.read(50)
            if not data:
                break  
            out.write(data)
    print(f"File '{input_file}' copied to '{output_file}' successfully.\n\n")
input_file = "C:/Users/KALIMI PRAKASH/file1.txt"
output_file = "C:/Users/KALIMI PRAKASH/output_file.txt"
solve(input_file, output_file)
with  open(output_file, 'r') as f:
    data = f.readlines()
print(data)
# Out:
# File 'C:/Users/KALIMI PRAKASH/file1.txt' copied to 'C:/Users/KALIMI PRAKASH/output_file.txt' successfully.
#
#
# ['Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.\n', 'Machine learning involves showing a large volume of data to a machine so that it can learn and make predictions, find patterns, or classify data. The three machine learning types are supervised, unsupervised, and reinforcement learning.']

# %% [markdown]
# # 2. print all numbers present in the text file and print the number of blank spaces in that file

# %%
import re
def nums_spaces(inp_file):
    nums = []
    space_count =0
    with open(inp_file, "r") as f:
        lines = f.readlines()
        for line in lines:
            nums.extend(re.findall(r"\d+", line))
            space_count += line.count(" ")     
    print("Numbers in file are: \n", nums)
    print("Num of spaces in  file are: ", space_count)
input_file = "C:/Users/KALIMI PRAKASH/textfile.txt"
nums_spaces(input_file)
# Out:
# Numbers in file are:
#  ['123', '456', '789', '11', '12', '13', '14']
# Num of spaces in  file are:  6

# %% [markdown]
# # 3. write a function called sed that takes as arguments a pattern string, a replacement string, and two filenames; it should read the first file and write the contents into the second file (creating it if necessary). if the pattern string appears anywhere in the file, it should be replaced with the replacement string. If an error occurs while opening, reading, writing, or closing files, your program should catch the exception, print an error message and exit

# %%
def sed(pattern, replacement, input_file, output_file):
    try:
        with open(input_file, 'r') as inp:
            data = inp.read()
        replaced_data = data.replace(pattern, replacement)
        with open(output_file, 'w') as out:
            out.write(replaced_data)
        print(f"File '{input_file}' processed and saved to '{output_file}' successfully.\n")
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.\n")
    except Exception as e:
        print(f"An error occurred: {e}\n")
pattern = 'Machine learning'
replacement = 'Python'
input_file = "C:/Users/KALIMI PRAKASH/file1.txt"
output_file = "C:/Users/KALIMI PRAKASH/file2.txt"
sed(pattern, replacement, input_file, output_file)
with  open(output_file, 'r') as f:
    data = f.readlines()
print(data)
# Out:
# File 'C:/Users/KALIMI PRAKASH/file1.txt' processed and saved to 'C:/Users/KALIMI PRAKASH/file2.txt' successfully.
#
# ['Python is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.\n', 'Python involves showing a large volume of data to a machine so that it can learn and make predictions, find patterns, or classify data. The three machine learning types are supervised, unsupervised, and reinforcement learning.']

# %% [markdown]
# # 4. Log File Analysis:

# %% [raw]
# You have a log file containing records of user activities on a
# website
# Each line in the file repersents a log entry with details
# like timestamp, user ID, and action performed.
# Your task is to analyze this log file
# a) write a python code to read the log file
#     and extract specific information, such as the number of
#     unique users or the most common action
# b) How would you handle large log files
#     efficiently without loading the entire file info memory?

# %%
from collections import Counter
def solve(log_file):
    try:
        unique_users = set()
        actn_counter = Counter()
        mst_cmn_actn = None
        mst_cmn_actn_count = 0
        with open(log_file, 'r') as file:
            for line in file:
                timestamp, user_id, action = line.strip().split(' ')
                unique_users.add(user_id)
                actn_counter[action] += 1     
                if actn_counter[action] > mst_cmn_actn_count:
                    mst_cmn_actn = action
                    mst_cmn_actn_count = actn_counter[action]
        print(f"Number of unique users: {len(unique_users)}")
        print(f"Most common action: {mst_cmn_actn} (count: {mst_cmn_actn_count})")
    except FileNotFoundError:
        print(f"Error: Log file '{log_file}' not found.\n")
    except Exception as e:
        print(f"An error occurred: {e}\n")
log_file = "C:/Users/KALIMI PRAKASH/Downloads/logfile.txt" 
solve(log_file)
# Out:
# An error occurred: too many values to unpack (expected 3)

# %% [markdown]
# # 5.Text file search and replace:

# %% [raw]
# # you have a text file with a large amount of text, and you want to search for specific words or phrases and replace them with new content a) write python code to search for and replace text within a text file b) how would you handle cases where you need to perform multiple replacements in a single pass?

# %%
def solve(input_file, output_file, replacements):
    try:
        with open(input_file, 'r') as inp, open(output_file, 'w') as out:
            data = inp.read()
            for pattern, replacement in replacements:
                data = data.replace(pattern, replacement)
            out.write(data)
        print(f"Replacements completed. Result saved to '{output_file}'.\n")
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.\n")
    except Exception as e:
        print(f"An error occurred: {e}\n")
input_file = "C:/Users/KALIMI PRAKASH/file1.txt"
output_file = "C:/Users/KALIMI PRAKASH/file2.txt"
replacements = [
    ('Machine Learning', 'Technology'),
    ('that', 'this'),
    ('data', 'operations')
]
solve(input_file, output_file, replacements)
# Out:
# Replacements completed. Result saved to 'C:/Users/KALIMI PRAKASH/file2.txt'.

# %% [markdown]
# # 6. write a python script that concatenates the contents of multiple text files into a single output file. Allow the user to specify the input files and the output file

# %%
def concatenate(input_files, output_file):
    try:
        with open(output_file, 'w') as output:
            for inp in input_files:
                with open(inp, 'r') as input:
                    data = input.read()
                    output.write(data)
                    output.write('\n')
        print(f"Concatenated files into '{output_file}' successfully.\n")
    except FileNotFoundError:
        print("Error: One or more input files not found.\n")
    except Exception as e:
        print(f"An error occurred: {e}\n")
input_files = []
while True:
    file = input("Enter an input file name (or 'done' to finish): ")
    if file.lower() == 'done':
        break
    input_files.append(file)
output_file = input("Enter the output file name: ")
concatenate(input_files, output_file)
# Out:
# Enter an input file name (or 'done' to finish): C:/Users/KALIMI PRAKASH/input1.txt
# Enter an input file name (or 'done' to finish): C:/Users/KALIMI PRAKASH/input2.txt
# Enter an input file name (or 'done' to finish): done
# Enter the output file name: C:/Users/KALIMI PRAKASH/outputfile.txt
# Concatenated files into 'C:/Users/KALIMI PRAKASH/outputfile.txt' successfully.

# %% [markdown]
# # 7: you are given a text file names input.txt containing a list of words

# %% [raw]
# one word per line your task is to create a python program that reads the contents of input.txt processess the words and writes the reesult to an output file name as output.txt
#
# a) the program should perform the following operations: i: Read the words from the input.txt ii: For each word in the input.txt fil, calculate the length of the word and store it in a dictionary where the work is a key and length is a value iii: write the word-length dictionary to output.txt in the folllowing format: iv: close both input and output files properly v: write a python code to accomplish this task, Ensure proper error handleing for file operations

# %%
def process_words(input_file, output_file):
    try:
        word_length = {}
        with open(input_file, 'r') as inp:
            words = inp.read().split()
            for word in words:
                word_length[word] = len(word)
        with open(output_file, 'w') as out:
            for word, length in word_length.items():
                out.write(f"{word}: {length}\n")
        print(f"Word lengths written to '{output_file}' successfully.\n")
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.\n")
    except Exception as e:
        print(f"An error occurred: {e}\n")
input_file = "C:/Users/KALIMI PRAKASH/file1.txt"
output_file = "C:/Users/KALIMI PRAKASH/outputfile.txt"
process_words(input_file, output_file)
with open(output_file, 'r') as f:
    data = f.read()
print(data)
# Out:
# Word lengths written to 'C:/Users/KALIMI PRAKASH/outputfile.txt' successfully.
#
# Machine: 7
# learning: 8
# is: 2
# a: 1
# branch: 6
# of: 2
# artificial: 10
# intelligence: 12
# (AI): 4
# and: 3
# computer: 8
# science: 7
# which: 5
# focuses: 7
# on: 2
# the: 3
# use: 3
# data: 4
# algorithms: 10
# to: 2
# imitate: 7
# way: 3
# that: 4
# humans: 6
# learn,: 6
# gradually: 9
# improving: 9
# its: 3
# accuracy.: 9
# involves: 8
# showing: 7
# large: 5
# volume: 6
# machine: 7
# so: 2
# it: 2
# can: 3
# learn: 5
# make: 4
# predictions,: 12
# find: 4
# patterns,: 9
# or: 2
# classify: 8
# data.: 5
# The: 3
# three: 5
# types: 5
# are: 3
# supervised,: 11
# unsupervised,: 13
# reinforcement: 13
# learning.: 9

# %% [markdown]
# # 8. Assume that you are developing a student gradeboook system for a school

# %% [raw]
# The system shoul allow teachers to input student grades for various subjects, Store the data in files and provide students with ability to view their grades
#
# i) Teachers should be able to input grades for students in different subjects ii) Store the student grade data in separate text files for each subject iii) Students should be able to view their grades for each subject iv) Implement error handling for file operations, such as file not found or permissionn issues

# %%
import os
def input_grades(subject):
    try:
        grades = {}
        while True:
            student_name = input(f"Enter student name for {subject} (or 'done' to finish): ")
            if student_name.lower() == 'done':
                break
            grade = input(f"Enter {student_name}'s grade for {subject}: ")
            grades[student_name] = grade
        with open(f'{subject}.txt', 'w') as file:
            for student, grade in grades.items():
                file.write(f"{student}: {grade}\n")
        print(f"Grades for {subject} saved successfully.")
    except Exception as e:
        print(f"An error occurred: {e}")
def view_grades(subject):
    try:
        if os.path.exists(f'{subject}.txt'):
            with open(f'{subject}.txt', 'r') as file:
                grades = file.read()
                print(f"Grades for {subject}:\n{grades}\n")
        else:
            print(f"Grades for {subject} are not available.\n")
    except Exception as e:
        print(f"An error occurred: {e}\n")
while True:
    choice = input("Select an option:\n1. Input Grades\n2. View Grades\n3. Quit\nEnter choice (1/2/3): ")
    if choice == '1':
        subject = input("Enter the subject: ")
        input_grades(subject)
    elif choice == '2':
        subject = input("Enter the subject: ")
        view_grades(subject)
    elif choice == '3':
        print("Exiting the program.")
        break
    else:
        print("Invalid choice. Please select 1, 2, or 3.")
# Out:
# Select an option:
# 1. Input Grades
# 2. View Grades
# 3. Quit
# Enter choice (1/2/3): 3
# Exiting the program.

# %%
import os
class GradebookSystem:
    def __init__(self, school_name):
        self.school_name = school_name
        self.data_directory = "grade_data"
        os.makedirs(self.data_directory, exist_ok=True)
    def input_grades(self, subject, student_name, grade):
        filename = os.path.join(self.data_directory, f"{subject}.txt")
        try:
            with open(filename, "a") as file:
                file.write(f"{student_name}: {grade}\n")
            print(f"Grade for {student_name} in {subject} saved successfully.")
        except FileNotFoundError:
            print("Error: File not found.")
        except PermissionError:
            print("Error: Permission denied while writing to file.")
        except Exception as e:
            print(f"An error occurred: {str(e)}")
    def view_grades(self, student_name):
        print(f"Grades for {student_name}:")
        for subject_file in os.listdir(self.data_directory):
            subject = os.path.splitext(subject_file)[0]
            filename = os.path.join(self.data_directory, subject_file)
            try:
                with open(filename, "r") as file:
                    for line in file:
                        data = line.strip().split(": ")
                        if len(data) == 2 and data[0] == student_name:
                            print(f"{subject}: {data[1]}")
            except FileNotFoundError:
                print(f"Error: File not found while reading {subject} grades.")
            except PermissionError:
                print(f"Error: Permission denied while reading {subject} grades.")
            except Exception as e:
                print(f"An error occurred: {str(e)}")
if __name__ == "__main__":
    gradebook = GradebookSystem("My School") 
    while True:
        print("\nOptions:")
        print("1. Input Grades")
        print("2. View Grades")
        print("3. Exit")
        choice = input("Enter your choice: ")
        if choice == "1":
            subject = input("Enter the subject: ")
            student_name = input("Enter the student's name: ")
            grade = input("Enter the grade: ")
            gradebook.input_grades(subject, student_name, grade)
        elif choice == "2":
            student_name = input("Enter the student's name: ")
            gradebook.view_grades(student_name)
        elif choice == "3":
            break
        else:
            print("Invalid choice. Please try again.")
# Out:
# Options:
# 1. Input Grades
# 2. View Grades
# 3. Exit
# Enter your choice: 3
